# %% [markdown]
# ### The project as described on Kaggle
#
# You are provided hourly rental data spanning two years. For this competition, the training set is comprised of the first 19 days of each month, while the test set is the 20th to the end of the month. You must predict the total count of bikes rented during each hour covered by the test set, using only information available prior to the rental period.
#
#
# #### Data Fields
# Field 0 contained the timestamp, fields 1 ... 8 were used for training. Field 11 for labeling/prediction.
#
# 0 - datetime - hourly date + timestamp
#
# 1 - season -  1 = spring, 2 = summer, 3 = fall, 4 = winter
#
# 2 - holiday - whether the day is considered a holiday
#
# 3 - workingday - whether the day is neither a weekend nor holiday
#
# 4 - weather - 1 = Clear, Few clouds, Partly cloudy, Partly cloudy, 2 = Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist, 3 = Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds, 4 = Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
#
# 5 - temp - temperature in Celsius
#
# 6 - atemp - "feels like" temperature in Celsius
#
# 7 - humidity - relative humidity
#
# 8 - windspeed - wind speed
#
# 9 - casual - number of non-registered user rentals initiated
#
# 10 - registered - number of registered user rentals initiated
#
# 11 - count - number of total rentals
#
#
# ### General ideas
#
# For this project I implemented a very simple version of a self-organizing map. It is an unsupervised learning method consisting of a 2D (here square) map of nodes which classify similar input vectors. Also, close nodes ('neighborhood') should represent close input vectors.
#
# An unsupervised algorithm doesn't provide predictions of actual outputs from the start. I addressed the need of a predicted output by labeling a node with the average of all its members (which resembles k-nearest neighbors.) A different approach could be to train a supervised method on all members of a given node.
#
# ### File structure
# Files accessed by this notebook are under train, e.g., train/train.csv . Files accessed by the testing notebook are under test/ . Some files are duplicated for clarity. Files like 'nodes.csv' which are shared by both notebooks are in the main directory . .
#
# ### Implementation comments
#
# The training data was normalized (large values in the input data would dominate the distance function between nodes and inputs and skew the training) and shuffled (to avoid getting stuck in local minima.)
#
# The self-organizing map gets initialized by providing the (square) number of nodes and the training data. Each node gets initialized with a different input vector from the training data.
#
# Training one input vector consists of finding the node with the smallest Euclidean distance from the input vector and updating the node and its surrounding nodes (neighborhood) by the difference between the node and the input mulitplied by the learning rate. Neighborhoods are squares and each node is updated in this implementation with the same weight. One training cycle consists of training each input once. The total number of training cycles can be chosen freely. Over the course of the training the learning rate and size of the neighborhood get reduced in a linear fashion (other functions are possible, e.g., exp(-x).) This will stabilize the model toward the end of the training.
#
# After the full training each node gets labeled with the average of its known training outputs. These labels are employed to predict the outputs for the test data.

# %%
from numpy import genfromtxt, savetxt, maximum, minimum
from numpy.linalg import norm
import random, math, pickle
import matplotlib.pyplot
import numpy.random

# configure matplotlib to show figures embedded in the notebook
# %pylab inline

#self-organizing map, assumed to be square, initialized with normalized data
class SOM :
    #initializes the nodes with normalized data, not random weights
    def __init__(self, nr_nodes, data) :
        #save length of one side of the map
        self.one_side = int(math.sqrt(nr_nodes) + 0.5)
        if self.one_side**2 != nr_nodes:
            raise ValueError('nr_nodes was not a perfect square')
        self.nodes = data[0::len(data)/nr_nodes][:nr_nodes]
            
    #save nodes to file
    def save_nodes(self, location) :
        pickle.dump(self.nodes, open(location, 'w'))
    
    #load nodes from file
    def load_nodes(self, location) :
        self.nodes = pickle.load(open(location, 'r'))
                    
    
    #returns the node with the closest Euclidian distance to a given input vector
    def find_winning_node(self, vector):
        min_value = norm(vector-self.nodes[0])
        min_count = 0
        for count in range(len(self.nodes)) :
            if(norm(vector-self.nodes[count]) < min_value) :
                min_value = norm(vector-self.nodes[count])
                min_count = count
        return min_count
    
    #update the neighborhood around the winning node
    #here we use a square neighborhood with the same weight to all updates inside
    def update_neighborhood(self, vector, winner, distance, learning_rate):
        #determine neighborhood - avoid leaving the map (don't go over borders)
        x = winner/self.one_side
        y = winner%self.one_side
        left = max(0,y-distance)
        right = min(self.one_side,y+distance+1)
        top = max(0,x-distance)
        bottom = min(self.one_side,x+distance+1)
        #update neighborhood
        for i in range(left,right):
            for j in range(top,bottom):
                k = self.one_side*j+i
                self.nodes[k] += learning_rate * (vector - self.nodes[k])

    #train each vector once
    def train_one_cycle(self, data, distance, learning_rate):
        node_count = [0]*len(self.nodes)
        for data_point in data :
            winner = self.find_winning_node(data_point)
            node_count[winner] += 1
            self.update_neighborhood(data_point, winner, distance, learning_rate)
        #show distribution of training vectors over nodes as a heatmap
        data = node_count
        heatmap = matplotlib.pyplot.pcolor(numpy.reshape( data, (self.one_side, self.one_side)), cmap=plt.cm.Blues)
        matplotlib.pyplot.show()
        matplotlib.pyplot.gca().invert_yaxis()

    #full training
    def train(self, data, nr_steps, distance, learning_rate):
        for i in range(0, nr_steps):
            #update distance and learning rate as necessary
            current_distance = distance - distance * i / nr_steps
            current_learning_rate = learning_rate - learning_rate * i / nr_steps
            print("step: {} distance: {} learning rate: {}".format(i, current_distance, current_learning_rate))
            self.train_one_cycle(data, current_distance, current_learning_rate)
            
    #labeling - make sure to use normalized data
    def label(self, data_with_labels):
        #determine average over all outputs in a given node
        node_label = [0.0]*len(self.nodes)
        node_label_count = [0]*len(self.nodes)
        #store average in node_prediction
        self.node_prediction = [0.0]*len(self.nodes)
        for data_point in data_with_labels:
            winner = self.find_winning_node(data_point[1:9])
            node_label[winner] += data_point[11]
            node_label_count[winner] += 1
        for j in range(len(self.nodes)):
            #empty nodes
            if(node_label_count[j] > 0):
                self.node_prediction[j] = node_label[j] / node_label_count[j]
        print("node labels: ")
        data = self.node_prediction
        heatmap = matplotlib.pyplot.pcolor(numpy.reshape( data, (self.one_side, self.one_side)), cmap=plt.cm.Blues)
        matplotlib.pyplot.show()
        matplotlib.pyplot.gca().invert_yaxis()
            
    #testing a single data point
    def test_datapoint(self, datapoint_without_labels):
        winner = self.find_winning_node(datapoint_without_labels[1:9])
        return [winner, datapoint_without_labels[0], self.node_prediction[winner]]
    
    #testing data set
    def test(self, data_without_labels):
        return [self.test_datapoint(datapoint) for datapoint in data_without_labels]
            
#create the training & test sets, skipping the header row with [1:]
train_dataset = genfromtxt(open('train/train.csv','r'), delimiter=',', dtype='f12')[1:]
train = [x[1:9] for x in train_dataset]

test_dataset = genfromtxt(open('train/test.csv','r'), delimiter=',', dtype='f12')[1:]
test = [x[1:9] for x in test_dataset]

train_april_dataset = genfromtxt(open('train/train_april.csv','r'), delimiter=',', dtype='f12')
train_10am_dataset = genfromtxt(open('train/train_10am.csv','r'), delimiter=',', dtype='f12')
train_6pm_dataset = genfromtxt(open('train/train_6pm.csv','r'), delimiter=',', dtype='f12')

#shuffle the training data set to avoid getting stuck in local minima
random.shuffle(train)

#determine min and max for all training inputs
max_inputs = train[0]
min_inputs = train[0]

for x in train :
    max_inputs = maximum( max_inputs, x)
    min_inputs = minimum( min_inputs, x)
    
print(max_inputs)
print(min_inputs)

#normalize data, assumes non-negativity
train /= max_inputs
for data_point in train_dataset:
    data_point[1:9] /= max_inputs
for data_point in test_dataset:
    data_point[1:9] /= max_inputs
for data_point in train_april_dataset:
    data_point[1:9] /= max_inputs
for data_point in train_10am_dataset:
    data_point[1:9] /= max_inputs
for data_point in train_6pm_dataset:
    data_point[1:9] /= max_inputs

#create and train the SOM
som = SOM(400, train)

#either train the SOM or load the pretrained weights - check size
#som.load_nodes('TpT/nodes.csv')
som.train(train, 100, 6, 0.2)

#test categorization power of the SOM by checking distribution of all April data points
print("labeling April data: ")
som.label(train_april_dataset)

#test categorization power of the SOM by checking distribution of all 10am data points
print("labeling 10am data: ")
som.label(train_10am_dataset)

#test categorization power of the SOM by checking distribution of all 6pm data points
print("labeling 6pm data: ")
som.label(train_6pm_dataset)

#label nodes with all data points for prediction
print("labeling all data: ")
som.label(train_dataset)

#test first 20 inputs from training and testing data
print("test test dataset: ")
print(som.test(test_dataset[:20]))
print("test train dataset: ")
print(som.test(train_dataset[:20]))

#predict on test data for submission - here only the first twenty data points for testing purposes
predicted = som.test(test_dataset[:20])

#save nodes to file - avoids retraining
som.save_nodes('nodes.csv')

#save the predictions to the file - only for testing purposes, still contains winning node in first column
#savetxt('train/test_submission.csv', predicted, delimiter=',', fmt ='%f,%f,%f', header='winner,time,rentals_all')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [   4.            1.            1.            4.           41.
#    45.45500183  100.           56.99689865]
# [ 1.          0.          0.          1.          0.81999999  0.75999999
#   0.          0.        ]
# step: 0 distance: 6 learning rate: 0.2
# WARNING: pylab import has clobbered these variables: ['random', 'test']
# `%matplotlib` prevents importing * from pylab and numpy
# step: 1 distance: 6 learning rate: 0.198
# step: 2 distance: 6 learning rate: 0.196
# step: 3 distance: 6 learning rate: 0.194
# step: 4 distance: 6 learning rate: 0.192
# step: 5 distance: 6 learning rate: 0.19
# step: 6 distance: 6 learning rate: 0.188
# step: 7 distance: 6 learning rate: 0.186
# step: 8 distance: 6 learning rate: 0.184
# step: 9 distance: 6 learning rate: 0.182
# step: 10 distance: 6 learning rate: 0.18
# step: 11 distance: 6 learning rate: 0.178
# step: 12 distance: 6 learning rate: 0.176
# step: 13 distance: 6 learning rate: 0.174
# step: 14 distance: 6 learning rate: 0.172
# step: 15 distance: 6 learning rate: 0.17
# step: 16 distance: 6 learning rate: 0.168
# step: 17 distance: 5 learning rate: 0.166
# step: 18 distance: 5 learning rate: 0.164
# step: 19 distance: 5 learning rate: 0.162
# step: 20 distance: 5 learning rate: 0.16
# step: 21 distance: 5 learning rate: 0.158
# step: 22 distance: 5 learning rate: 0.156
# step: 23 distance: 5 learning rate: 0.154
# step: 24 distance: 5 learning rate: 0.152
# step: 25 distance: 5 learning rate: 0.15
# step: 26 distance: 5 learning rate: 0.148
# step: 27 distance: 5 learning rate: 0.146
# step: 28 distance: 5 learning rate: 0.144
# step: 29 distance: 5 learning rate: 0.142
# step: 30 distance: 5 learning rate: 0.14
# step: 31 distance: 5 learning rate: 0.138
# step: 32 distance: 5 learning rate: 0.136
# step: 33 distance: 5 learning rate: 0.134
# step: 34 distance: 4 learning rate: 0.132
# step: 35 distance: 4 learning rate: 0.13
# step: 36 distance: 4 learning rate: 0.128
# step: 37 distance: 4 learning rate: 0.126
# step: 38 distance: 4 learning rate: 0.124
# step: 39 distance: 4 learning rate: 0.122
# step: 40 distance: 4 learning rate: 0.12
# step: 41 distance: 4 learning rate: 0.118
# step: 42 distance: 4 learning rate: 0.116
# step: 43 distance: 4 learning rate: 0.114
# step: 44 distance: 4 learning rate: 0.112
# step: 45 distance: 4 learning rate: 0.11
# step: 46 distance: 4 learning rate: 0.108
# step: 47 distance: 4 learning rate: 0.106
# step: 48 distance: 4 learning rate: 0.104
# step: 49 distance: 4 learning rate: 0.102
# step: 50 distance: 3 learning rate: 0.1
# step: 51 distance: 3 learning rate: 0.098
# step: 52 distance: 3 learning rate: 0.096
# step: 53 distance: 3 learning rate: 0.094
# step: 54 distance: 3 learning rate: 0.092
# step: 55 distance: 3 learning rate: 0.09
# step: 56 distance: 3 learning rate: 0.088
# step: 57 distance: 3 learning rate: 0.086
# step: 58 distance: 3 learning rate: 0.084
# step: 59 distance: 3 learning rate: 0.082
# step: 60 distance: 3 learning rate: 0.08
# step: 61 distance: 3 learning rate: 0.078
# step: 62 distance: 3 learning rate: 0.076
# step: 63 distance: 3 learning rate: 0.074
# step: 64 distance: 3 learning rate: 0.072
# step: 65 distance: 3 learning rate: 0.07
# step: 66 distance: 3 learning rate: 0.068
# step: 67 distance: 2 learning rate: 0.066
# step: 68 distance: 2 learning rate: 0.064
# step: 69 distance: 2 learning rate: 0.062
# step: 70 distance: 2 learning rate: 0.06
# step: 71 distance: 2 learning rate: 0.058
# step: 72 distance: 2 learning rate: 0.056
# step: 73 distance: 2 learning rate: 0.054
# step: 74 distance: 2 learning rate: 0.052
# step: 75 distance: 2 learning rate: 0.05
# step: 76 distance: 2 learning rate: 0.048
# step: 77 distance: 2 learning rate: 0.046
# step: 78 distance: 2 learning rate: 0.044
# step: 79 distance: 2 learning rate: 0.042
# step: 80 distance: 2 learning rate: 0.04
# step: 81 distance: 2 learning rate: 0.038
# step: 82 distance: 2 learning rate: 0.036
# step: 83 distance: 2 learning rate: 0.034
# step: 84 distance: 1 learning rate: 0.032
# step: 85 distance: 1 learning rate: 0.03
# step: 86 distance: 1 learning rate: 0.028
# step: 87 distance: 1 learning rate: 0.026
# step: 88 distance: 1 learning rate: 0.024
# step: 89 distance: 1 learning rate: 0.022
# step: 90 distance: 1 learning rate: 0.02
# step: 91 distance: 1 learning rate: 0.018
# step: 92 distance: 1 learning rate: 0.016
# step: 93 distance: 1 learning rate: 0.014
# step: 94 distance: 1 learning rate: 0.012
# step: 95 distance: 1 learning rate: 0.01
# step: 96 distance: 1 learning rate: 0.008
# step: 97 distance: 1 learning rate: 0.006
# step: 98 distance: 1 learning rate: 0.004
# step: 99 distance: 1 learning rate: 0.002
# labeling April data:
# node labels:
# labeling 10am data:
# node labels:
# labeling 6pm data:
# node labels:
# labeling all data:
# node labels:
# test test dataset:
# [[361, 2.011012e+09, 120.88888888888889], [282, 2.011012e+09, 79.760000000000005], [282, 2.011012e+09, 79.760000000000005], [283, 2.011012e+09, 91.761904761904759], [283, 2.011012e+09, 91.761904761904759], [263, 2.011012e+09, 111.0], [263, 2.011012e+09, 111.0], [283, 2.011012e+09, 91.761904761904759], [340, 2.011012e+09, 61.100000000000001], [280, 2.011012e+09, 89.896551724137936], [341, 2.011012e+09, 78.75], [280, 2.011012e+09, 89.896551724137936], [260, 2.011012e+09, 98.51428571428572], [280, 2.011012e+09, 89.896551724137936], [280, 2.011012e+09, 89.896551724137936], [280, 2.011012e+09, 89.896551724137936], [280, 2.011012e+09, 89.896551724137936], [260, 2.011012e+09, 98.51428571428572], [280, 2.011012e+09, 89.896551724137936], [264, 2.011012e+09, 103.85714285714286]]
# test train dataset:
# [[100, 2.01101e+09, 45.294117647058826], [100, 2.01101e+09, 45.294117647058826], [100, 2.01101e+09, 45.294117647058826], [80, 2.01101e+09, 28.204081632653061], [80, 2.01101e+09, 28.204081632653061], [120, 2.01101e+09, 68.285714285714292], [100, 2.01101e+09, 45.294117647058826], [100, 2.01101e+09, 45.294117647058826], [80, 2.01101e+09, 28.204081632653061], [101, 2.01101e+09, 57.846153846153847], [102, 2.01101e+09, 69.07692307692308], [101, 2.01101e+09, 57.846153846153847], [122, 2.01101e+09, 299.33333333333331], [142, 2.0110102e+09, 102.39344262295081], [142, 2.0110102e+09, 102.39344262295081], [142, 2.0110102e+09, 102.39344262295081], [142, 2.0110102e+09, 102.39344262295081], [142, 2.0110102e+09, 102.39344262295081], [141, 2.0110102e+09, 46.153846153846153], [141, 2.0110102e+09, 46.153846153846153]]

# %% [markdown]
# ### Training
# Training picks up slowly. A substantial amount of the data is stuck in the corners. (This could be addressed with a toroidal or spherical map.) The size of the neighborhoods is slightly visible on the map. With the shrinking neighborhood distance and learning rate the inputs are more evenly distributed over the map. The neighborhoods get visibly smaller. Due to the linear reduction this effect only takes place in the last 20 training steps (out of 100.) An exponential reduction could speed up this process.
#
# ### Labeling
# The April data are concentrated in 3 to 4 clusters on the SOM. This is reassuring since the actual timestamp was not employed in training the map. However, season data were one of the inputs which distinguishes April, May and June from the remaining months.
#
# The 10am data are more evenly distributed over the map. There is still a visible concentration in the northern regions of the map, whereas the 6pm data seem to be distributed in the same fashion as all the data.
#
# ### Testing
# In this 'debug' version the testing data are triple reporting the winning node (0..399), the timestamp, and the predicted number of bicycle rentals.
